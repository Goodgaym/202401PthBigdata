# %%
import gdown
import pandas as pd

# 아래 두개의 값 입력 (로컬 컴퓨터 환경에서 실행은 url 비워둘 것)
filename = 'pt_book_fix.csv'  # 예제에서 사용할 filename 입력
url = ''    # 여기에 본인이 가진 링크의 난수 입력

if url != '' :
    gdown.download(f'https://drive.google.com/uc?id={url}', filename, quiet=False)
    dir = ''
else :
    dir = '../_csv/'  # 로컬 컴퓨터 환경에서 사용할 dir (예제는 _csv)

pt_book = pd.read_csv(f'{dir}{filename}', low_memory=False)
pt_book.head()
# Out:
#    번호                                도서명              저자   출판사  발행년도  \
# 0   1                           세이노의 가르침          세이노 지음   데이원  2023
# 1   2                         서울대생의 비밀과외  소린TV,안소린 [공]지음  다산에듀  2023
# 2   3  (현직 고등학교 선생님들이 직접 고른) 생기부 필독서 100        주경아 외 지음   센시오  2023
# 3   4                        당연하게도 나는 너를          이꽃님 지음  우리학교  2023
# 4   5                             고요한 우연          김수빈 지음  문학동네  2023
#
#           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9.79117E+12      NaN    0  NaN  199.1     1     0  2023-03-30
# 1  9.79113E+12      NaN    1  NaN  373.7     1     0  2023-03-30
# 2  9.79117E+12      NaN    1  NaN  376.6     1     0  2023-03-30
# 3  9.79117E+12      NaN    4  NaN  813.7     1     0  2023-03-30
# 4  9.78895E+12      NaN    0  NaN  813.7     1     0  2023-03-30

# %%
import matplotlib.pyplot as plt
# matplotlib 패키지 적용
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## 산점도

# %%
plt.scatter([1,2,3,4], [1,2,3,4])
plt.show()

# %%
plt.scatter(pt_book['번호'], pt_book['대출건수'])
plt.show()

# %%
plt.scatter(pt_book['도서권수'], pt_book['대출건수'])
plt.show()

# %%
plt.scatter(pt_book['도서권수'], pt_book['대출건수'], alpha=0.1)
plt.show()

# %%
average_borrows = pt_book['대출건수']/pt_book['도서권수']
plt.scatter(average_borrows, pt_book['대출건수'], alpha=0.1)
plt.show()

# %%
plt.scatter(pt_book['도서권수'], pt_book['대출건수'], alpha=0.1, marker='+')    # 마커를 +로
plt.show()

# %%
plt.figure(figsize=(9, 6))  # 너비, 높이 (기본 6, 4) 인치
plt.scatter(pt_book['도서권수'], pt_book['대출건수'], alpha=0.1)
plt.show()

# %%
print(plt.rcParams['figure.dpi'])   # 기본 DPI 확인
# Out:
# 100.0

# %%
plt.figure(figsize=(900/72, 600/72))    # 900, 600 픽셀에 72 DPI
plt.scatter(pt_book['도서권수'], pt_book['대출건수'], alpha=0.1)
plt.show()

# %%
# %config InlineBackend.print_figure_kwargs = {'bbox_inches':None}
plt.figure(figsize=(900/72, 600/72))
plt.scatter(pt_book['도서권수'], pt_book['대출건수'], alpha = 0.1)
plt.show()
